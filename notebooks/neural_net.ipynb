# %% [markdown]
# # **Multi-Precision Neural Network**
# *   Implementation of a classical neural network classifier supporting multi-precision training.
# *   Implementation currently supports training in either double, single, or half precision.
# *   Implementation is based off of TensorFlow's very own example: [TensorFlow Neural Network Tutorial](https://www.tensorflow.org/tutorials/keras/classification)

# %%
import time
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import fashion_mnist

# %%
# Define number of training runs to compute the average training time over
NUM_TRAINING_RUNS = 5
# Values are specific to the Fashion MNIST dataset
INPUT_DIM = 28
NUM_CLASSES = 10

# %%
def build_and_train(X_train, y_train, precision):
    if precision == 'double':
        dtype = tf.float64
    elif precision == 'single':
        dtype = tf.float32
    else: # half
        dtype = tf.float16

    model = models.Sequential([
        layers.Flatten(input_shape=(INPUT_DIM, INPUT_DIM)),
        layers.Dense(128, activation='relu', dtype=dtype),
        layers.Dense(NUM_CLASSES, dtype=dtype)
    ])
    model.compile(optimizer='adam',
                  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                  metrics=['accuracy'])
    start_time = time.time()
    model.fit(X_train, y_train, epochs=5)
    end_time = time.time()
    training_time = end_time - start_time

    return model, training_time

# %%
# Load dataset and split into train and test sets
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Scale values before feeding into neural net
X_train = X_train / 255.0
X_test  = X_test / 255.0

# %%
# Test run to make sure that everything is working properly before starting actual measurements
_ = build_and_train(X_train, y_train, precision='single')
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4965 - accuracy: 0.8248
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3736 - accuracy: 0.8639
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3321 - accuracy: 0.8782
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3094 - accuracy: 0.8871
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2925 - accuracy: 0.8919

# %%
# Train with double precision
time_double = 0.0
for _ in range(NUM_TRAINING_RUNS):
    model_double, training_time = build_and_train(X_train, y_train, 'double')
    time_double += training_time
accuracy_double = model_double.evaluate(X_test, y_test, verbose=2)[1]
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.4997 - accuracy: 0.8241
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3719 - accuracy: 0.8663
# Epoch 3/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3347 - accuracy: 0.8771
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3100 - accuracy: 0.8860
# Epoch 5/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2922 - accuracy: 0.8924
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5042 - accuracy: 0.8225
# Epoch 2/5
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3769 - accuracy: 0.8630
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3379 - accuracy: 0.8764
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3137 - accuracy: 0.8840
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2954 - accuracy: 0.8907
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.4976 - accuracy: 0.8258
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3746 - accuracy: 0.8648
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3355 - accuracy: 0.8772
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3120 - accuracy: 0.8854
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2946 - accuracy: 0.8916
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.5003 - accuracy: 0.8245
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3784 - accuracy: 0.8629
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3373 - accuracy: 0.8779
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3136 - accuracy: 0.8850
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2964 - accuracy: 0.8910
# Epoch 1/5
# 1875/1875 [==============================] - 8s 3ms/step - loss: 0.4978 - accuracy: 0.8240
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3760 - accuracy: 0.8650
# Epoch 3/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3379 - accuracy: 0.8759
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.3130 - accuracy: 0.8845
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2952 - accuracy: 0.8913
# 313/313 - 1s - loss: 0.3492 - accuracy: 0.8728 - 794ms/epoch - 3ms/step

# %%
# Train with single precision
time_single = 0.0
for _ in range(NUM_TRAINING_RUNS):
    model_single, training_time = build_and_train(X_train, y_train, 'single')
    time_single += training_time
accuracy_single = model_single.evaluate(X_test, y_test, verbose=2)[1]
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.5005 - accuracy: 0.8227
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3795 - accuracy: 0.8632
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3377 - accuracy: 0.8778
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3158 - accuracy: 0.8847
# Epoch 5/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2984 - accuracy: 0.8899
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4990 - accuracy: 0.8250
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3734 - accuracy: 0.8656
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3379 - accuracy: 0.8754
# Epoch 4/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3153 - accuracy: 0.8836
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2958 - accuracy: 0.8914
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4950 - accuracy: 0.8249
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3715 - accuracy: 0.8653
# Epoch 3/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3341 - accuracy: 0.8782
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3116 - accuracy: 0.8880
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2943 - accuracy: 0.8920
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4988 - accuracy: 0.8252
# Epoch 2/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3757 - accuracy: 0.8648
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3388 - accuracy: 0.8772
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3135 - accuracy: 0.8854
# Epoch 5/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2949 - accuracy: 0.8918
# Epoch 1/5
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4994 - accuracy: 0.8249
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3781 - accuracy: 0.8656
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3379 - accuracy: 0.8777
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3127 - accuracy: 0.8849
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2956 - accuracy: 0.8915
# 313/313 - 1s - loss: 0.3458 - accuracy: 0.8740 - 613ms/epoch - 2ms/step

# %%
# Train with half precision
time_half = 0.0
for _ in range(NUM_TRAINING_RUNS):
    model_half, training_time = build_and_train(X_train, y_train, 'half')
    time_half += training_time
accuracy_half = model_half.evaluate(X_test, y_test, verbose=2)[1]
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 22.6092 - accuracy: 0.6677
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 6.3962 - accuracy: 0.7716
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 4.4459 - accuracy: 0.7935
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 3.4642 - accuracy: 0.8043
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.8653 - accuracy: 0.8123
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 18.5638 - accuracy: 0.6822
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 3.4376 - accuracy: 0.7828
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.3869 - accuracy: 0.8016
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.9205 - accuracy: 0.8141
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.6417 - accuracy: 0.8199
# Epoch 1/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 6.9063 - accuracy: 0.7087
# Epoch 2/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.8178 - accuracy: 0.7829
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.1062 - accuracy: 0.8017
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.6446 - accuracy: 0.8131
# Epoch 5/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 1.3797 - accuracy: 0.8189
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 15.8526 - accuracy: 0.6952
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.7966 - accuracy: 0.7789
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.0547 - accuracy: 0.7973
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.6562 - accuracy: 0.8095
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.4651 - accuracy: 0.8169
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 8.5967 - accuracy: 0.7028
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 3.2680 - accuracy: 0.7867
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 2.5369 - accuracy: 0.8017
# Epoch 4/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 2.0300 - accuracy: 0.8120
# Epoch 5/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 1.7231 - accuracy: 0.8196
# 313/313 - 1s - loss: 2.2283 - accuracy: 0.7972 - 684ms/epoch - 2ms/step

# %%
print("---RESULTS---")
print("Average training time in double precision:", time_double / NUM_TRAINING_RUNS, "seconds")
print("Average training time in single precision:", time_single/ NUM_TRAINING_RUNS, "seconds")
print("Average training time in half   precision:", time_half/ NUM_TRAINING_RUNS, "seconds")
print("-------------")
print("Accuracy with double precision:", accuracy_double)
print("Accuracy with single precision:", accuracy_single)
print("Accuracy with half   precision:", accuracy_single)
# Out:
# ---RESULTS---
# Average training time in double precision: 38.0335075378418 seconds
# Average training time in single precision: 35.54670648574829 seconds
# Average training time in half   precision: 30.058187770843507 seconds
# -------------
# Accuracy with double precision: 0.8727999925613403
# Accuracy with single precision: 0.8740000128746033
# Accuracy with half   precision: 0.8740000128746033
